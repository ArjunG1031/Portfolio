# %% [markdown]
# ---
# layout: post
# codemirror: true
# microblog: true
# title: HW Summation
# description: Full HW Summation
# permalink: /js/hwsummation
# author: Arjun
# ---

# %% [markdown]
# ## Homeworks
#
# - [Strings Homework](https://arjung1031.github.io/Portfolio/2026/01/27/Strings-homework_IPYNB_2_.html)
# - [Classes](https://arjung1031.github.io/Portfolio/js/classes)
# - [Booleans](https://arjung1031.github.io/Portfolio/js/booleans)
# - [Math](https://arjung1031.github.io/Portfolio/js/math)
# - [JSON](https://arjung1031.github.io/Portfolio/js/json)
# - [Data Abstraction](https://arjung1031.github.io/Portfolio/js/dataabstraction)
# - [Nested Conditionals](https://arjung1031.github.io/Portfolio/js/nested-conditionals)
# - [Iterations](https://arjung1031.github.io/Portfolio/js/iterationshw)
# - [Variables](https://arjung1031.github.io/Portfolio/js/variables)

# %%
# %%js
# // CODE_RUNNER: Nested Conditonals Hw
#
# for (let i = 1; i <= 50; i++) {
#   console.log("Number:", i);
#
#   if (i % 1 === 0) {
#     console.log("  Divisible by 1");
#
#     if (i % 2 === 0) {
#       console.log("  Divisible by 2");
#     }
#
#     if (i % 5 === 0) {
#       console.log("  Divisible by 5");
#     }
#
#     if (i % 10 === 0) {
#       console.log("  Divisible by 10");
#     }
#
#     if (i % 25 === 0) {
#       console.log("  Divisible by 25");
#     }
#
#     if (i % 50 === 0) {
#       console.log("  Divisible by 50");
#     }
#   }
# }

# %%
# %%js
# // CODE_RUNNER: Data Abstraction Hw 1
#
# function calculator(num1, num2, operator) {
#     let result;
#
#     if (operator === "+") {
#         result = num1 + num2;
#     } else if (operator === "-") {
#         result = num1 - num2;
#     } else if (operator === "*") {
#         result = num1 * num2;
#     } else if (operator === "/") {
#         result = num1 / num2;
#     } else {
#         result = "Invalid operator";
#     }
#
#     return result;
# }
#
# console.log(calculator(10, 5, "+"));
# console.log(calculator(10, 5, "-"));
# console.log(calculator(10, 5, "*"));
# console.log(calculator(10, 5, "/"));
#
# console.log(calculator(10, 5, "/"));

# %%
# %%js
# // CODE_RUNNER: Data Abstraction Hw 2
#
# class Pet {
#     eat() {
#         console.log("Nom nom nom");
#     }
# }
#
# // Dog class that inherits from Pet
# class Dog extends Pet {
#     bark() {
#         console.log("Woof woof!");
#     }
# }
#
# // Test the Dog class
# let myDog = new Dog();
# myDog.eat();   // Inherited from Pet
# myDog.bark();  // Dog's own method
#
#
# //

# %%
# %%js
# // CODE_RUNNER: Booleans
#
# function isPositiveAndOdd(num) {
#     let isPositive = num > 0;
#     let isOdd = num % 2 !== 0;
#     return isPositive && isOdd;
# }
#
# console.log(isPositiveAndOdd(7));  // true
# console.log(isPositiveAndOdd(8));  // false

# %%
# %%js
# // CODE_RUNNER: Json and Javascript Objects
#
# // 1. Create a JavaScript object named `resume`
# const resume = {
#     fullName: "Arjun Ganesh",
#     email: "arjun.redranger@gmail.com",
#     education: "9th Grade at DNHS",
#     address: {
#         city: "San Diego",
#         state: "California",
#         country: "USA"
#     },
#     skills: ["JavaScript", "Problem Solving","Basketball","Cybersecurity Basics"]
# };
#
# // 2. Access and display properties using dot notation
# console.log(resume.fullName);
# console.log(resume.email);
# console.log(resume.address.city);
#
# // 3. Convert the object into a JSON string
# const jsonString = JSON.stringify(resume);
# console.log(jsonString);
#
# // 4. Parse the JSON string back into a JavaScript object
# const parsedResume = JSON.parse(jsonString);
# console.log(parsedResume);

# %%
# %%js
# // CODE_RUNNER: Strings
#
# // Three strings of varying lengths
# let str1 = "Hello";
# let str2 = "JavaScript";
# let str3 = "is awesome!";
#
# // Find and print the length of each string
# console.log(`Length of str1: ${str1.length}`);
# console.log(`Length of str2: ${str2.length}`);
# console.log(`Length of str3: ${str3.length}`);
#
# // Find and print the first and last character of each string
# console.log(`str1 first: ${str1[0]}, last: ${str1[str1.length - 1]}`);
# console.log(`str2 first: ${str2[0]}, last: ${str2[str2.length - 1]}`);
# console.log(`str3 first: ${str3[0]}, last: ${str3[str3.length - 1]}`);
#
# // Concatenate all three strings into a sentence using string interpolation
# let sentence = `${str1} ${str2} ${str3}`;
# console.log(sentence);

# %%
# %%js
# // CODE_RUNNER: Math Exp 1 Hw
#
# let y = 25;
#
# if (y % 5 === 0) {
#   console.log(y + " is divisible by 5");
# } else {
#   console.log(y + " is not divisible by 5");
# }

# %%
# %%js
# // CODE_RUNNER: Math Exp 2 Hw
#
# let a = 10;
# let b = 20;
# let sum = a + b;
#
# console.log("The sum is:", sum);

# %%
# %%js
# // CODE_RUNNER: Iterations Hw
#
# let fruits = ["Heart Shaped Herb", "Yami Yami no Mi", "Gomu Gomu no Mi"];
#
# // Loop 1: Forward
# for (let i = 0; i < fruits.length; i++) {
#     console.log("Forward: " + fruits[i]);
# }
#
# // Loop 2: Backward
# for (let i = fruits.length - 1; i >= 0; i--) {
#     console.log("Backward: " + fruits[i]);
# }

# %%
# %%js
# // CODE_RUNNER: Classes and Methods Hw
#
# class VideoGame {
#     constructor(name, genre) {
#         this.name = name;
#         this.genre = genre;
#     }
#
#     play() {
#         console.log("You are now playing " + this.name + "!");
#     }
#
#     describe() {
#         console.log(this.name + " is a " + this.genre + " game.");
#     }
# }
#
# // Create an object
# let game1 = new VideoGame("Galaxy Battle", "Action");
#
# // Call the methods
# game1.play();
# game1.describe();
